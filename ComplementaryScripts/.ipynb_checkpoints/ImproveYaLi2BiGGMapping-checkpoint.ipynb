# %%
from cobra.io import read_sbml_model
from six import string_types
import re

# %%
yali = read_sbml_model("../ModelFiles/xml/iYali.xml")

# %%
pattern = re.compile('s_[0-9]+')
unmapped_mets = [met for met in yali.metabolites if re.findall(pattern, met.id)]
len(unmapped_mets)
# Out:
# 385

# %%
pattern = re.compile('y[0-9]+')
unmapped_rxns = [rxn for rxn in yali.reactions if re.findall(pattern, rxn.id)]
len(unmapped_rxns)
# Out:
# 1543

# %%
iMM904 = read_sbml_model("../../../Downloads/iMM904.xml")

# %% [markdown]
# If the name of a metabolite in iYali matches a name in iMM904 then transfer the BiGG and MetaNetX IDs of the latter to the former.

# %%
duplicate_mapping = []
mapped_from_to = 'Based on its name {}, {} can be mapped to {}, {}'
for met_a in unmapped_mets:
    for met_b in iMM904.metabolites:
        if met_a.name.lower() == met_b.name.lower() and met_a.compartment == met_b.compartment:
            print(mapped_from_to.format(met_a.name, met_a.id, met_b.name, met_b.id))
            met_a.annotation.setdefault('bigg.metabolite', met_b.annotation['bigg.metabolite'])
            if 'metanetx.chemical' in met_b.annotation:
                met_a.annotation.setdefault('metanetx.chemical', met_b.annotation['metanetx.chemical'])
            met_a.annotation["standard.metabolite"] = met_a.id
            try: 
                met_a.id = met_a.annotation["bigg.metabolite"] + "_" + met_a.compartment
                yali.repair()
            except ValueError:
                duplicate_mapping.append(met_a)
# Out:
# Based on its name 2-methylcitrate, s_0174 can be mapped to 2-Methylcitrate, 2mcit_m
# Based on its name 5,10-methylenetetrahydrofolate, s_0306 can be mapped to 5,10-Methylenetetrahydrofolate, mlthf_c
# Based on its name 5,10-methylenetetrahydrofolate, s_0307 can be mapped to 5,10-Methylenetetrahydrofolate, mlthf_m
# Based on its name D-fructose, s_0553 can be mapped to D-Fructose, fru_c
# Based on its name D-fructose, s_0554 can be mapped to D-Fructose, fru_e
# Based on its name D-fructose 1,6-bisphosphate, s_0555 can be mapped to D-Fructose 1,6-bisphosphate, fdp_c
# Based on its name D-fructose 1-phosphate, s_0556 can be mapped to D-Fructose 1-phosphate, f1p_c
# Based on its name D-fructose 6-phosphate, s_0557 can be mapped to D-Fructose 6-phosphate, f6p_c
# Based on its name D-mannose 1-phosphate, s_0573 can be mapped to D-Mannose 1-phosphate, man1p_c
# Based on its name D-mannose 6-phosphate, s_0574 can be mapped to D-Mannose 6-phosphate, man6p_c
# Based on its name L-homocysteine, s_1012 can be mapped to L-Homocysteine, hcys__L_c
# Based on its name pantetheine 4'-phosphate, s_1307 can be mapped to Pantetheine 4'-phosphate, pan4p_c
# Based on its name potassium, s_1373 can be mapped to Potassium, k_c
# Based on its name potassium, s_1374 can be mapped to Potassium, k_e
# Based on its name sodium, s_1437 can be mapped to Sodium, na1_c
# Based on its name sodium, s_1438 can be mapped to Sodium, na1_e
# Based on its name trehalose, s_1520 can be mapped to Trehalose, tre_c
# Based on its name trehalose, s_1521 can be mapped to Trehalose, tre_e
# Based on its name trehalose, s_1522 can be mapped to Trehalose, tre_v
# Based on its name pantetheine 4'-phosphate, s_1308 can be mapped to Pantetheine 4'-phosphate, pan4p_m

# %%
pattern = re.compile('s_[0-9]+')
unmapped_mets = [met for met in yali.metabolites if re.findall(pattern, met.id)]
len(unmapped_mets)
# Out:
# 365

# %% [markdown]
# Since this was only semi-successful I'm going to try this again with fuzzy string search using the packages `Fuzzywuzzy` and `python-Levenshtein`.

# %%
import fuzzywuzzy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-8d8a7fd5f3e4> in <module>
# ----> 1 import fuzzywuzzy
#
# ModuleNotFoundError: No module named 'fuzzywuzzy'

# %%
[(met.id, met.name) for met in unmapped_mets]
# Out:
# [('s_0001', '(1-3)-beta-D-glucan'),
#  ('s_0003', '(1-3)-beta-D-glucan'),
#  ('s_0004', '(1-6)-beta-D-glucan'),
#  ('s_0012', '(2S,3R)-3-hydroxybutane-1,2,3-tricarboxylic acid'),
#  ('s_0015', '(N(omega)-L-arginino)succinic acid'),
#  ('s_0086', '1-C-(indol-3-yl)glycerol 3-phosphate'),
#  ('s_0116', '1-pyrroline-3-hydroxy-5-carboxylic acid'),
#  ('s_0117', '1-pyrroline-3-hydroxy-5-carboxylic acid'),
#  ('s_0122', '14-demethyllanosterol'),
#  ('s_0123', '1D-myo-inositol 1,3,4,5-tetrakisphosphate'),
#  ('s_0124', '1D-myo-inositol 1,4,5,6-tetrakisphosphate'),
#  ('s_0125', '1D-myo-inositol 1,4,5-trisphosphate'),
#  ('s_0142', '2,5-diamino-6-(5-phosphono)ribitylamino-4(3H)-pyrimidinone'),
#  ('s_0146', '2-acetyllactic acid'),
#  ('s_0154', '2-hexaprenyl-5-hydroxy-6-methoxy-3-methyl-1,4-benzoquinone'),
#  ('s_0155', '2-hexaprenyl-6-methoxy-1,4-benzoquinone'),
#  ('s_0156', '2-hexaprenyl-6-methoxy-3-methyl-1,4-benzoquinone'),
#  ('s_0162', '2-isopropylmalate'),
#  ('s_0193', "3',5'-cyclic CMP"),
#  ('s_0194', "3',5'-cyclic dAMP"),
#  ('s_0196', "3',5'-cyclic IMP"),
#  ('s_0209', '3-dehydro-4-methylzymosterol'),
#  ('s_0234', '3-methylbutanal'),
#  ('s_0236', '3-methylbutanal'),
#  ('s_0262', '4,4-dimethyl-5alpha-cholesta-8,14,24-trien-3beta-ol'),
#  ('s_0263', '4,5-bis(diphospho)-1D-myo-inositol tetrakisphosphate'),
#  ('s_0279', '4-diphospho-1D-myo-inositol pentakisphosphate'),
#  ('s_0296', '4alpha-methylzymosterol'),
#  ('s_0297', '4beta-methylzymosterol-4alpha-carboxylic acid'),
#  ('s_0302', "5'-phosphoribosyl-N-formylglycineamidine"),
#  ('s_0308', '5,6,7,8-tetrahydrofolyl-L-glutamic acid'),
#  ('s_0309', '5,6-bis(diphospho)-1D-myo-inositol tetrakisphosphate'),
#  ('s_0330', '6-(alpha-D-glucosaminyl)-O-acyl-1-phosphatidyl-1D-myo-inositol'),
#  ('s_0332',
#   '6-[6-(2-aminoethylphosphoryl)-alpha-mannosyl-(1-6)-2-(2-aminoethylphosphoryl)-alpha-mannosyl-(1-6)-alpha-2-(2-aminoethylphosphoryl)mannosyl-(1-4)-alpha-glucosaminyl]-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]'),
#  ('s_0333', '6-diphospho-1D-myo-inositol pentakisphosphate'),
#  ('s_0334',
#   '6-O-[alpha-D-mannosyl-(1-4)-alpha-D-glucosaminyl]-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]'),
#  ('s_0337',
#   '6-O-{2-O-[(2-aminoethyl)phosphoryl]-alpha-D-mannosyl-(1-4)-alpha-D-glucosaminyl}-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]'),
#  ('s_0338',
#   '6-O-{alpha-D-mannosyl-(1-2)-alpha-D-mannosyl-(1-6)-2-O-[(2-aminoethyl)phosphoryl]-alpha-D-mannosyl-(1-4)-alpha-D-glucosaminyl}-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]'),
#  ('s_0339',
#   '6-O-{alpha-D-mannosyl-(1-6)-2-O-[(2-aminoethyl)phosphoryl]-alpha-D-mannosyl-(1-4)-alpha-D-glucosaminyl}-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]'),
#  ('s_0346', "7,8-dihydroneopterin 3'-triphosphate"),
#  ('s_0389', "adenosine 2'-phosphate"),
#  ('s_0412', 'alpha-D-glucosamine 6-phosphate'),
#  ('s_0414',
#   'alpha-D-mannosyl-beta-D-mannosyldiacetylchitobiosyldiphosphodolichol'),
#  ('s_0432', 'Asp-tRNA(Asp)'),
#  ('s_0433', 'Asp-tRNA(Asp)'),
#  ('s_0443', 'beta-D-mannosyldiacetylchitobiosyldiphosphodolichol'),
#  ('s_0444', 'beta-D-mannosyldiacetylchitobiosyldiphosphodolichol'),
#  ('s_0453', "biotinyl-5'-AMP"),
#  ('s_0475', 'ceramide-1 (C24)'),
#  ('s_0476', 'ceramide-1 (C24)'),
#  ('s_0477', 'ceramide-1 (C24)'),
#  ('s_0478', 'ceramide-1 (C26)'),
#  ('s_0479', 'ceramide-1 (C26)'),
#  ('s_0480', 'ceramide-1 (C26)'),
#  ('s_0481', 'ceramide-2 (C24)'),
#  ('s_0482', 'ceramide-2 (C24)'),
#  ('s_0483', 'ceramide-2 (C24)'),
#  ('s_0484', 'ceramide-2 (C26)'),
#  ('s_0485', 'ceramide-2 (C26)'),
#  ('s_0486', 'ceramide-2 (C26)'),
#  ('s_0487', "ceramide-2' (C24)"),
#  ('s_0488', "ceramide-2' (C24)"),
#  ('s_0489', "ceramide-2' (C24)"),
#  ('s_0490', "ceramide-2' (C26)"),
#  ('s_0491', "ceramide-2' (C26)"),
#  ('s_0492', "ceramide-2' (C26)"),
#  ('s_0493', 'ceramide-3 (C24)'),
#  ('s_0494', 'ceramide-3 (C24)'),
#  ('s_0495', 'ceramide-3 (C24)'),
#  ('s_0496', 'ceramide-3 (C26)'),
#  ('s_0497', 'ceramide-3 (C26)'),
#  ('s_0498', 'ceramide-3 (C26)'),
#  ('s_0499', 'ceramide-4 (C24)'),
#  ('s_0500', 'ceramide-4 (C24)'),
#  ('s_0501', 'ceramide-4 (C24)'),
#  ('s_0502', 'ceramide-4 (C26)'),
#  ('s_0503', 'ceramide-4 (C26)'),
#  ('s_0504', 'ceramide-4 (C26)'),
#  ('s_0507', 'cerotic acid'),
#  ('s_0548', 'D-arabinose'),
#  ('s_0600', 'decanoate'),
#  ('s_0607', 'dehydro-D-arabinono-1,4-lactone'),
#  ('s_0640', 'docosaprenyl diphosphate'),
#  ('s_0641', 'dodecaprenyl diphosphate'),
#  ('s_0645', 'dolichyl phosphate'),
#  ('s_0646', 'dolichyl phosphate'),
#  ('s_0664', 'ergosta-5,7,24(28)-trien-3beta-ol'),
#  ('s_0670', 'ergosterol 3-beta-D-glucoside'),
#  ('s_0685', 'ethyl acetate'),
#  ('s_0710', 'ferrocytochrome c'),
#  ('s_0813', 'henicosaprenyl diphosphate'),
#  ('s_0814', 'heptadecaprenyl diphosphate'),
#  ('s_0816', 'hexacosanoyl-CoA'),
#  ('s_0817', 'hexacosanoyl-CoA'),
#  ('s_0819', 'hexacosanoyl-CoA'),
#  ('s_0829', 'hexadecaprenyl diphosphate'),
#  ('s_0834', 'homocitrate'),
#  ('s_0835', 'homocitrate'),
#  ('s_0836', 'homoisocitrate'),
#  ('s_0845', 'icosaprenyl diphosphate'),
#  ('s_0861', 'inositol phosphomannosylinositol phosphoceramide A (C24)'),
#  ('s_0863', 'inositol phosphomannosylinositol phosphoceramide A (C24)'),
#  ('s_0864', 'inositol phosphomannosylinositol phosphoceramide A (C26)'),
#  ('s_0866', 'inositol phosphomannosylinositol phosphoceramide A (C26)'),
#  ('s_0867', 'inositol phosphomannosylinositol phosphoceramide B (C24)'),
#  ('s_0869', 'inositol phosphomannosylinositol phosphoceramide B (C24)'),
#  ('s_0870', 'inositol phosphomannosylinositol phosphoceramide B (C26)'),
#  ('s_0872', 'inositol phosphomannosylinositol phosphoceramide B (C26)'),
#  ('s_0873', "inositol phosphomannosylinositol phosphoceramide B' (C24)"),
#  ('s_0875', "inositol phosphomannosylinositol phosphoceramide B' (C24)"),
#  ('s_0876', "inositol phosphomannosylinositol phosphoceramide B' (C26)"),
#  ('s_0878', "inositol phosphomannosylinositol phosphoceramide B' (C26)"),
#  ('s_0879', 'inositol phosphomannosylinositol phosphoceramide C (C24)'),
#  ('s_0881', 'inositol phosphomannosylinositol phosphoceramide C (C24)'),
#  ('s_0882', 'inositol phosphomannosylinositol phosphoceramide C (C26)'),
#  ('s_0884', 'inositol phosphomannosylinositol phosphoceramide C (C26)'),
#  ('s_0885', 'inositol phosphomannosylinositol phosphoceramide D (C24)'),
#  ('s_0887', 'inositol phosphomannosylinositol phosphoceramide D (C24)'),
#  ('s_0888', 'inositol phosphomannosylinositol phosphoceramide D (C26)'),
#  ('s_0890', 'inositol phosphomannosylinositol phosphoceramide D (C26)'),
#  ('s_0894', 'inositol-P-ceramide A (C24)'),
#  ('s_0895', 'inositol-P-ceramide A (C24)'),
#  ('s_0896', 'inositol-P-ceramide A (C24)'),
#  ('s_0897', 'inositol-P-ceramide A (C26)'),
#  ('s_0898', 'inositol-P-ceramide A (C26)'),
#  ('s_0899', 'inositol-P-ceramide A (C26)'),
#  ('s_0900', 'inositol-P-ceramide B (C24)'),
#  ('s_0901', 'inositol-P-ceramide B (C24)'),
#  ('s_0902', 'inositol-P-ceramide B (C24)'),
#  ('s_0903', 'inositol-P-ceramide B (C26)'),
#  ('s_0904', 'inositol-P-ceramide B (C26)'),
#  ('s_0905', 'inositol-P-ceramide B (C26)'),
#  ('s_0906', "inositol-P-ceramide B' (C24)"),
#  ('s_0907', "inositol-P-ceramide B' (C24)"),
#  ('s_0908', "inositol-P-ceramide B' (C24)"),
#  ('s_0909', "inositol-P-ceramide B' (C26)"),
#  ('s_0910', "inositol-P-ceramide B' (C26)"),
#  ('s_0911', "inositol-P-ceramide B' (C26)"),
#  ('s_0912', 'inositol-P-ceramide C (C24)'),
#  ('s_0913', 'inositol-P-ceramide C (C24)'),
#  ('s_0914', 'inositol-P-ceramide C (C24)'),
#  ('s_0915', 'inositol-P-ceramide C (C26)'),
#  ('s_0916', 'inositol-P-ceramide C (C26)'),
#  ('s_0917', 'inositol-P-ceramide C (C26)'),
#  ('s_0918', 'inositol-P-ceramide D (C24)'),
#  ('s_0919', 'inositol-P-ceramide D (C24)'),
#  ('s_0920', 'inositol-P-ceramide D (C24)'),
#  ('s_0921', 'inositol-P-ceramide D (C26)'),
#  ('s_0922', 'inositol-P-ceramide D (C26)'),
#  ('s_0923', 'inositol-P-ceramide D (C26)'),
#  ('s_0951', 'keto-phenylpyruvate'),
#  ('s_1043', 'L-sorbose'),
#  ('s_1070', 'laurate'),
#  ('s_1085', 'lignoceric acid'),
#  ('s_1109', 'mannose-(1D-myo-inositol 1-phosphate)2'),
#  ('s_1110', 'mannose-(1D-myo-inositol 1-phosphate)2'),
#  ('s_1116', 'mannosylinositol phosphorylceramide A (C24)'),
#  ('s_1118', 'mannosylinositol phosphorylceramide A (C24)'),
#  ('s_1119', 'mannosylinositol phosphorylceramide A (C26)'),
#  ('s_1121', 'mannosylinositol phosphorylceramide A (C26)'),
#  ('s_1122', 'mannosylinositol phosphorylceramide B (C24)'),
#  ('s_1124', 'mannosylinositol phosphorylceramide B (C24)'),
#  ('s_1125', 'mannosylinositol phosphorylceramide B (C26)'),
#  ('s_1127', 'mannosylinositol phosphorylceramide B (C26)'),
#  ('s_1128', "mannosylinositol phosphorylceramide B' (C24)"),
#  ('s_1130', "mannosylinositol phosphorylceramide B' (C24)"),
#  ('s_1131', "mannosylinositol phosphorylceramide B' (C26)"),
#  ('s_1133', "mannosylinositol phosphorylceramide B' (C26)"),
#  ('s_1134', 'mannosylinositol phosphorylceramide C (C24)'),
#  ('s_1136', 'mannosylinositol phosphorylceramide C (C24)'),
#  ('s_1137', 'mannosylinositol phosphorylceramide C (C26)'),
#  ('s_1139', 'mannosylinositol phosphorylceramide C (C26)'),
#  ('s_1140', 'mannosylinositol phosphorylceramide D (C24)'),
#  ('s_1142', 'mannosylinositol phosphorylceramide D (C24)'),
#  ('s_1143', 'mannosylinositol phosphorylceramide D (C26)'),
#  ('s_1145', 'mannosylinositol phosphorylceramide D (C26)'),
#  ('s_1148', 'Met-tRNA(Met)'),
#  ('s_1149', 'Met-tRNA(Met)'),
#  ('s_1156', 'myo-inositol 1,3,4,5,6-pentakisphosphate'),
#  ('s_1157', 'myo-inositol 1,3,4,5,6-pentakisphosphate'),
#  ('s_1166', 'myristate'),
#  ('s_1189', 'N-acetyl-alpha-D-glucosamine 1-phosphate'),
#  ('s_1229', 'nonadecaprenyl diphosphate'),
#  ('s_1230', 'nonaprenyl 4-hydroxybenzoate'),
#  ('s_1231', 'nonaprenyl diphosphate'),
#  ('s_1232', 'nonaprenyl diphosphate'),
#  ('s_1246', 'octadecaprenyl diphosphate'),
#  ('s_1254', 'octanoyl-ACP'),
#  ('s_1298', 'palmitoleate'),
#  ('s_1310', 'pentadecaprenyl diphosphate'),
#  ('s_1371', 'polysulphur'),
#  ('s_1388', "pseudouridine 5'-phosphate"),
#  ('s_1428', 'Ser-tRNA(Ser)'),
#  ('s_1479', 'tetracosanoyl-CoA'),
#  ('s_1480', 'tetracosanoyl-CoA'),
#  ('s_1482', 'tetracosanoyl-CoA'),
#  ('s_1483', 'tetradecaprenyl diphosphate'),
#  ('s_1489', 'thiamine'),
#  ('s_1523', 'tridecaprenyl diphosphate'),
#  ('s_1526', 'trimethylenediamine'),
#  ('s_1541', 'UDP-D-galactose'),
#  ('s_1542', 'UDP-D-galactose'),
#  ('s_1565', 'xanthosine-5-phosphate'),
#  ('s_1578', 'zymosterol intermediate 1c'),
#  ('s_1616', 'TRX1'),
#  ('s_1617', 'TRX1'),
#  ('s_1618', 'TRX1'),
#  ('s_1619', 'TRX1'),
#  ('s_2763', 'kynurenic acid'),
#  ('s_2771', 'butanoyl-ACP'),
#  ('s_2773', 'hexanoyl-ACP'),
#  ('s_2775', '3-hydroxybutanoyl-ACP'),
#  ('s_2777', '3-hydroxyoctanoyl-ACP'),
#  ('s_2778', 'trans-but-2-enoyl-ACP'),
#  ('s_2780', 'trans-oct-2-enoyl-ACP'),
#  ('s_2793', 'icosanoyl-CoA'),
#  ('s_2797', 'tetracosanoyl-CoA'),
#  ('s_2806', '3-hydroxytetracosanoyl-CoA'),
#  ('s_2807', '(S)-3-hydroxyhexacosanoyl-CoA'),
#  ('s_2810', 'trans-hexadec-2-enoyl-CoA'),
#  ('s_2812', 'trans-icos-2-enoyl-CoA'),
#  ('s_2813', 'trans-docos-2-enoyl-CoA'),
#  ('s_2814', 'trans-tetracos-2-enoyl-CoA'),
#  ('s_2816', 'hexacosanoyl-CoA'),
#  ('s_2819', 'palmitoleoyl-CoA'),
#  ('s_2832', 'laurate'),
#  ('s_2835', 'myristate'),
#  ('s_2837', 'palmitoleate'),
#  ('s_2841', 'laurate'),
#  ('s_2844', 'myristate'),
#  ('s_2848', 'palmitoleate'),
#  ('s_2849', 'palmitoleoyl-CoA'),
#  ('s_2854', 'palmitoleoyl-CoA'),
#  ('s_2858', 'arachidate'),
#  ('s_2861', 'icosanoyl-CoA'),
#  ('s_2862', 'behenate'),
#  ('s_2864', 'lignoceric acid'),
#  ('s_2865', 'tetracosanoyl-CoA'),
#  ('s_2866', 'cerotic acid'),
#  ('s_2867', 'hexacosanoyl-CoA'),
#  ('s_2868', 'behenate'),
#  ('s_2869', 'lignoceric acid'),
#  ('s_2870', 'cerotic acid'),
#  ('s_2871', 'behenate'),
#  ('s_2873', 'lignoceric acid'),
#  ('s_2874', 'tetracosanoyl-CoA'),
#  ('s_2875', 'cerotic acid'),
#  ('s_2876', 'hexacosanoyl-CoA'),
#  ('s_2877', 'palmitoleoyl-CoA'),
#  ('s_2878', 'icosanoyl-CoA'),
#  ('s_2879', 'icosanoyl-CoA'),
#  ('s_2882', 'butyrate'),
#  ('s_2885', 'hexanoyl-CoA'),
#  ('s_2889', 'trans-icos-2-enoyl-CoA'),
#  ('s_2890', 'trans-docos-2-enoyl-CoA'),
#  ('s_2891', 'trans-tetracos-2-enoyl-CoA'),
#  ('s_2892', 'trans-2,cis-9-hexadecadienoyl-CoA'),
#  ('s_2893', 'cis-tetradec-7-enoyl-CoA'),
#  ('s_2894', 'trans-2,cis-7-tetradecadienoyl-CoA'),
#  ('s_2895', 'cis-dodec-5-enoyl-CoA'),
#  ('s_2896', 'trans-2,cis-5-dodecadienoyl-CoA'),
#  ('s_2898', 'cis-hexadec-7-enoyl-CoA'),
#  ('s_2899', 'trans-2,cis-7-hexadecadienoyl-CoA'),
#  ('s_2900', 'cis-tetradec-5-enoyl-CoA'),
#  ('s_2901', 'trans-2,cis-5-tetradecadienoyl-CoA'),
#  ('s_2920', '3-oxo-cis-hexadec-9-enoyl-CoA'),
#  ('s_2921', '3-oxo-cis-tetradec-7-enoyl-CoA'),
#  ('s_2922', '3-oxo-cis-dodec-5-enoyl-CoA'),
#  ('s_2923', '3-oxo-cis-octadec-9-enoyl-CoA'),
#  ('s_2924', '3-oxo-cis-hexadec-7-enoyl-CoA'),
#  ('s_2925', '3-oxo-cis-tetradec-5-enoyl-CoA'),
#  ('s_2926', 'cis-dec-3-enoyl-CoA'),
#  ('s_2927', 'cis-dodec-3-enoyl-CoA'),
#  ('s_2929', 'trans-dodec-3-enoyl-CoA'),
#  ('s_2931', 'trans-tetradec-3-enoyl-CoA'),
#  ('s_2932', 'trans-2,trans-4-dodecadienoyl-CoA'),
#  ('s_2933', 'trans-2,trans-4-tetradecadienoyl-CoA'),
#  ('s_3442', 'ergosteryl oleate'),
#  ('s_3443', 'ergosteryl palmitoleate'),
#  ('s_3451', 'palmitoleate'),
#  ('s_3490', 'sn-glycero-3-phosphoserine'),
#  ('s_3498', '1D-myo-inositol 1,4,5-trisphosphate'),
#  ('s_3656', 'ergosteryl palmitoleate'),
#  ('s_3658', 'ergosteryl oleate'),
#  ('s_3659', 'episteryl palmitoleate'),
#  ('s_3661', 'episteryl oleate'),
#  ('s_3662', 'fecosteryl palmitoleate'),
#  ('s_3663', 'fecosteryl oleate'),
#  ('s_3664', 'lanosteryl palmitoleate'),
#  ('s_3666', 'lanosteryl oleate'),
#  ('s_3667', 'zymosteryl palmitoleate'),
#  ('s_3668', 'zymosteryl oleate'),
#  ('s_3669', 'zymosteryl palmitoleate'),
#  ('s_3670', 'zymosteryl oleate'),
#  ('s_0013', '(5S,6S)-di-HETE'),
#  ('s_0014', '(5S,6S)-di-HETE'),
#  ('s_0045', '(S)-3-hydroxyhexacosanoyl-CoA'),
#  ('s_0164', '2-isopropylmalate'),
#  ('s_0608', 'Delta(6)-trans,Delta(8)-cis-leukotriene B4'),
#  ('s_0609', 'Delta(6)-trans,Delta(8)-cis-leukotriene B4'),
#  ('s_1081', 'leukotriene B4'),
#  ('s_1082', 'leukotriene B4'),
#  ('s_1576', 'zymosterol intermediate 1a'),
#  ('s_1577', 'zymosterol intermediate 1b'),
#  ('s_2902', '(R)-3-hydroxybutanoyl-CoA'),
#  ('s_2903', '(R)-3-hydroxyhexanoyl-CoA'),
#  ('s_2904', '(R)-3-hydroxyoctanoyl-CoA'),
#  ('s_2905', '(R)-3-hydroxyicosanoyl-CoA'),
#  ('s_2906', '(R)-3-hydroxydocosanoyl-CoA'),
#  ('s_2907', '(R)-3-hydroxytetracosanoyl-CoA'),
#  ('s_2908', '(R)-3-hydroxy-cis-hexadec-9-enoyl-CoA'),
#  ('s_2909', '(R)-3-hydroxy-cis-tetradec-7-enoyl-CoA'),
#  ('s_2910', '(R)-3-hydroxy-cis-dodec-5-enoyl-CoA'),
#  ('s_2911', '(R)-3-hydroxy-cis-octadec-9-enoyl-CoA'),
#  ('s_2912', '(R)-3-hydroxy-cis-hexadec-7-enoyl-CoA'),
#  ('s_2913', '(R)-3-hydroxy-cis-tetradec-5-enoyl-CoA'),
#  ('s_0163', '2-isopropylmalate'),
#  ('s_0235', '3-methylbutanal'),
#  ('s_0413', 'alpha-D-glucosamine 6-phosphate'),
#  ('s_0450', 'biomass'),
#  ('s_0549', 'D-arabinose'),
#  ('s_0597', 'decanoate'),
#  ('s_0686', 'ethyl acetate'),
#  ('s_1044', 'L-sorbose'),
#  ('s_1067', 'laurate'),
#  ('s_1163', 'myristate'),
#  ('s_1295', 'palmitoleate'),
#  ('s_1490', 'thiamine'),
#  ('s_2766', '14-demethyllanosterol'),
#  ('s_2822', 'butyrate'),
#  ('s_0002', '(1-3)-beta-D-glucan'),
#  ('s_0595', 'decanoate'),
#  ('s_0862', 'inositol phosphomannosylinositol phosphoceramide A (C24)'),
#  ('s_0865', 'inositol phosphomannosylinositol phosphoceramide A (C26)'),
#  ('s_0868', 'inositol phosphomannosylinositol phosphoceramide B (C24)'),
#  ('s_0871', 'inositol phosphomannosylinositol phosphoceramide B (C26)'),
#  ('s_0874', "inositol phosphomannosylinositol phosphoceramide B' (C24)"),
#  ('s_0877', "inositol phosphomannosylinositol phosphoceramide B' (C26)"),
#  ('s_0880', 'inositol phosphomannosylinositol phosphoceramide C (C24)'),
#  ('s_0883', 'inositol phosphomannosylinositol phosphoceramide C (C26)'),
#  ('s_0886', 'inositol phosphomannosylinositol phosphoceramide D (C24)'),
#  ('s_0889', 'inositol phosphomannosylinositol phosphoceramide D (C26)'),
#  ('s_1065', 'laurate'),
#  ('s_1117', 'mannosylinositol phosphorylceramide A (C24)'),
#  ('s_1120', 'mannosylinositol phosphorylceramide A (C26)'),
#  ('s_1123', 'mannosylinositol phosphorylceramide B (C24)'),
#  ('s_1126', 'mannosylinositol phosphorylceramide B (C26)'),
#  ('s_1129', "mannosylinositol phosphorylceramide B' (C24)"),
#  ('s_1132', "mannosylinositol phosphorylceramide B' (C26)"),
#  ('s_1135', 'mannosylinositol phosphorylceramide C (C24)'),
#  ('s_1138', 'mannosylinositol phosphorylceramide C (C26)'),
#  ('s_1141', 'mannosylinositol phosphorylceramide D (C24)'),
#  ('s_1144', 'mannosylinositol phosphorylceramide D (C26)'),
#  ('s_1161', 'myristate'),
#  ('s_1293', 'palmitoleate'),
#  ('s_2828', 'butyrate'),
#  ('s_3320', 'palmitoleoyl-CoA'),
#  ('s_3433', 'episteryl oleate'),
#  ('s_3434', 'episteryl palmitoleate'),
#  ('s_3436', 'fecosteryl oleate'),
#  ('s_3437', 'fecosteryl palmitoleate'),
#  ('s_3439', 'lanosteryl oleate'),
#  ('s_3440', 'lanosteryl palmitoleate'),
#  ('s_3445', 'zymosteryl oleate'),
#  ('s_3446', 'zymosteryl palmitoleate')]
